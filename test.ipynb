# %%
import pandas as pd
df = pd.read_csv('schedules.csv')
df
# Out:
#        000007000002000300    7  \
# 0      000007000003000310    7
# 1      000007000004000320    7
# 2      000007000004000330    7
# 3      000007065535000010    7
# 4      000007065535000020    7
# ...                   ...  ...
# 12644    0004446553500014  444
# 12645    0004446553500015  444
# 12646    0004446553500016  444
# 12647    0004446553500017  444
# 12648    0004446553500018  444
#
#       {"endTime": "2017-07-26 11:00:00", "startTime": "2017-07-26 10:15:00"}  \
# 0      {"endTime": "2017-07-26 11:00:00", "startTime"...
# 1      {"endTime": "2017-07-26 09:21:00", "startTime"...
# 2      {"endTime": "2017-07-26 09:21:00", "startTime"...
# 3      {"endTime": "2017-07-25 09:40:00", "startTime"...
# 4      {"endTime": "2017-07-25 09:40:00", "startTime"...
# ...                                                  ...
# 12644  {"endTime": "2019-09-26 19:19:15", "startTime"...
# 12645  {"endTime": "2019-09-26 19:34:15", "startTime"...
# ...
